# %% [markdown]
# ## Cross Validation

# %%
# Useful starting lines
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from proj1_helpers import *
DATA_TRAIN_PATH = '../data/train.csv' # TODO: download train data and supply path here 
y, tX, ids = load_csv_data(DATA_TRAIN_PATH, sub_sample=False)

# %%
y = pd.read_pickle("../pickles/y2_full.pkl").to_numpy()
tX = pd.read_pickle("../pickles/x2_full.pkl").to_numpy()

y = np.reshape(y, len(y))

y.shape
# Out:
# (72543,)

# %%
from cross_validation import cross_validation_least_squares

losses = cross_validation_least_squares(y, tX)

# %%
def plot_losses(losses):
    
    fig = plt.figure(figsize=(8,6))
    plt.plot(losses.degree, losses.losses_tr)
    plt.plot(losses.degree, losses.losses_te)
    plt.grid()
    plt.ylim([0,3])
    plt.show()

# %%
plot_losses(losses)
